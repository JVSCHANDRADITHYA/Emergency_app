# %%
import pandas as pd
import numpy as np

# Load CSVs
df_acc = pd.read_csv("dataset\Accelerometer.csv")
# df_ori = pd.read_csv("dataset\Orientation.csv")
df_mag = pd.read_csv("dataset\Magnetometer.csv")

# df_grav = pd.read_csv("dataset\gravity.csv")

df = pd.merge(df_acc, df_mag, on="time", how='outer')

# %%
df
# Out:
#                        time  seconds_elapsed_x  ...        m_y        m_x
# 0       1742660711980776400                NaN  ...  19.912500  22.256250
# 1       1742660712000437200           0.196437  ...        NaN        NaN
# 2       1742660712000774400                NaN  ... -26.812502 -32.156250
# 3       1742660712020763400                NaN  ... -26.887501 -32.287502
# 4       1742660712024279600           0.220280  ...        NaN        NaN
# ...                     ...                ...  ...        ...        ...
# 171843  1742664331356884700        3619.552885  ...        NaN        NaN
# 171844  1742664331372786400        3619.568786  ...        NaN        NaN
# 171845  1742664331373676800                NaN  ...  10.312500  32.587502
# 171846  1742664331388686300        3619.584686  ...        NaN        NaN
# 171847  1742664331393681000                NaN  ...   9.843750  32.812500
#
# [171848 rows x 9 columns]
